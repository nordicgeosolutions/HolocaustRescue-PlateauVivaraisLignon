# %%
# Load basic libraries
import pandas as pd
import os
import re
from pandas import json_normalize
import numpy as np

# Set model to use GPU
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# ALL Keywords extracted from:  Rules-Based Entity Ruler Custom-built Geoparser

# %%
## Reading in the csv file, from FRENCH language Rules-Based NLP results, of the extracted names and coordinates of
## the towns, villages, and named features of the Plateau, creating a pandas dataframe with these locations and their
## coordinates, then creating a list of just the location names, which then becomes one of the lists of keywords.

df_PlatLoc = pd.read_csv("YOUR_DATA_keywords")
df_PlatLoc = df_PlatLoc.dropna()
df_PlatLoc = df_PlatLoc[["Plateau_Locations", "LAT", "LON", "ALT"]]
df_PlatLoc["LAT"] = pd.to_numeric(df_PlatLoc["LAT"], downcast="float")
df_PlatLoc["LON"] = pd.to_numeric(df_PlatLoc["LON"], downcast="float")
df_PlatLoc["ALT"] = pd.to_numeric(df_PlatLoc["ALT"], downcast="float")
df_PlatLoc.columns = ["Plateau_Locations", "LAT", "LON", "ALT"]
print(df_PlatLoc)
PlatLoc = df_PlatLoc["Plateau_Locations"].to_list()
print(PlatLoc)
# Out:
#         Plateau_Locations        LAT       LON     ALT
# 0                 Chambon  45.060810  4.302941   961.0
# 1      Chambon sur Lignon  45.060810  4.302941   961.0
# 2      Chambon-sur-Lignon  45.060810  4.302941   961.0
# 3            Chaumargeais  45.090061  4.344000  1004.0
# 4                     Fay  44.985435  4.226421  1181.0
# 5          Fay-sur-Lignon  44.985435  4.226421  1181.0
# 6                Fourezon  45.087067  4.248799  1041.0
# 7               Freycenet  45.077240  4.216540  1047.0
# 8            La Papeterie  45.132137  4.284565   822.0
# 9   Le Chambon-sur-Lignon  45.060810  4.302941   961.0
# 10            Le Fourezon  45.087067  4.248799  1041.0
# 11              le Lignon  45.060810  4.302941   961.0
# 12            Mazelgirard  45.082169  4.280830   969.0
# 13                  Mazet  45.047192  4.244734  1027.0
# 14        Mazet-Saint-Voy  45.047192  4.244734  1027.0
# 15                 Mézenc  44.914280  4.189920  1744.0
# ...

# %%
## Reading in the csv file, from FRENCH language Rules-Based NLP results, of the extracted names and coordinates of
## the other locations in France (not on Plateau), creating a pandas dataframe with these locations and their
## coordinates, then creating a list of just the location names, which then becomes one of the lists of keywords.

df_FranceLoc = pd.read_csv("YOUR_DATA_keywords")
df_FranceLoc = df_FranceLoc.dropna()
df_FranceLoc = df_FranceLoc[["other_French_Locations", "LAT", "LON", "ALT"]]
df_FranceLoc["LAT"] = pd.to_numeric(df_FranceLoc["LAT"], downcast="float")
df_FranceLoc["LON"] = pd.to_numeric(df_FranceLoc["LON"], downcast="float")
df_FranceLoc["ALT"] = pd.to_numeric(df_FranceLoc["ALT"], downcast="float")
df_FranceLoc.columns = ["other_French_Locations", "LAT", "LON", "ALT"]
print(df_FranceLoc)
FranceLoc = df_FranceLoc["other_French_Locations"].to_list()
print(FranceLoc)
# Out:
#    other_French_Locations        LAT      LON    ALT
# 0            camp de Gurs  43.273762 -0.74031  186.0
# 1                  Drancy  48.925831  2.44528   47.0
# 2                 Dunière  44.823132  4.65988  151.0
# 3                 Etienne  45.433891  4.39000  529.0
# 4                 Étienne  45.433891  4.39000  529.0
# 5                    Gurs  43.273762 -0.74031  186.0
# 6                    Lyon  45.748459  4.84671  173.0
# 7               Marseille  43.296951  5.38107   28.0
# 8                Mulhouse  47.752048  7.32866  238.0
# 9                   Paris  48.853409  2.34880   42.0
# 10                    Puy  45.043659  3.88523  640.0
# 11                  Rouen  49.443130  1.09932   21.0
# 12         Sainte-Étienne  45.433891  4.39000  529.0
# 13          Saint-Etienne  45.433891  4.39000  529.0
# 14          Saint-Étienne  45.433891  4.39000  529.0
# 15             Yssingeaux  45.142818  4.12372  864.0
# ...

# %%
## Reading in the csv file, from FRENCH language Rules-Based NLP results, of the extracted names and coordinates of
## the Childrens Homes on the Plateau, creating a pandas dataframe with these locations and their
## coordinates, then creating a list of just the location names, which then becomes one of the lists of keywords.

df_homes = pd.read_csv("YOUR_DATA_keywords")
df_homes = df_homes.dropna()
df_homes = df_homes[["Childrens_Homes", "LAT", "LON", "ALT"]]
df_homes["LAT"] = pd.to_numeric(df_homes["LAT"], downcast="float")
df_homes["LON"] = pd.to_numeric(df_homes["LON"], downcast="float")
df_homes["ALT"] = pd.to_numeric(df_homes["ALT"], downcast="float")
df_homes.columns = ["Childrens_Homes", "LAT", "LON", "ALT"]
print(df_homes)
homes = df_homes["Childrens_Homes"].to_list()
print(homes)
# Out:
#       Childrens_Homes        LAT       LON     ALT
# 0            Airelles  45.066315  4.305011   995.0
# 1            Grillons  45.071281  4.326289  1067.0
# 2      Heures Claires  45.063877  4.309932   981.0
# 3      Joyeuse-Nichée  45.060829  4.311157  1002.0
# 4           La Ruchée  45.062370  4.306548   994.0
# 5        Les Grillons  45.071281  4.326289  1067.0
# 6  Les Heures Claires  45.063877  4.309932   981.0
# 7              Ruchée  45.062370  4.306548   994.0
# 8          Tante Soly  45.060757  4.304197   958.0
# ['Airelles', 'Grillons', 'Heures Claires', 'Joyeuse-Nichée', 'La Ruchée', 'Les Grillons', 'Les Heures Claires', 'Ruchée', 'Tante Soly']

# %%
## Reading in the csv file, from FRENCH language Rules-Based NLP results, of the extracted names and coordinates of
## the Farms on the Plateau, creating a pandas dataframe with these locations and their
## coordinates, then creating a list of just the location names, which then becomes one of the lists of keywords.

df_farms = pd.read_csv("YOUR_DATA_keywords")
df_farms = df_farms.dropna()
df_farms = df_farms[["Farms", "LAT", "LON", "ALT"]]
df_farms["LAT"] = pd.to_numeric(df_farms["LAT"], downcast="float")
df_farms["LON"] = pd.to_numeric(df_farms["LON"], downcast="float")
df_farms["ALT"] = pd.to_numeric(df_farms["ALT"], downcast="float")
df_farms.columns = ["Farms", "LAT", "LON", "ALT"]
print(df_farms)
farms = df_farms["Farms"].to_list()
print(farms)
# Out:
#         Farms        LAT       LON     ALT
# 0  Les Digons  45.036205  4.371174  1084.0
# 1     Remière  45.042877  4.323951  1053.0
# ['Les Digons', 'Remière']

# %%
## Reading in the csv file, from FRENCH language Rules-Based NLP results, of the extracted names and coordinates of
## the hotels used by the Germans on the Plateau, creating a pandas dataframe with these locations and their
## coordinates, then creating a list of just the location names, which then becomes one of the lists of keywords.

df_hotels = pd.read_csv("YOUR_DATA_keywords")
df_hotels = df_hotels.dropna()
df_hotels = df_hotels[["Hotels_GermanConvalescence", "LAT", "LON", "ALT"]]
df_hotels["LAT"] = pd.to_numeric(df_hotels["LAT"], downcast="float")
df_hotels["LON"] = pd.to_numeric(df_hotels["LON"], downcast="float")
df_hotels["ALT"] = pd.to_numeric(df_hotels["ALT"], downcast="float")
df_hotels.columns = ["Hotels_GermanConvalescence", "LAT", "LON", "ALT"]
print(df_hotels)
hotels = df_hotels["Hotels_GermanConvalescence"].to_list()
print(hotels)
# Out:
#   Hotels_GermanConvalescence        LAT      LON    ALT
# 0            hôtel du Lignon  45.060642  4.30448  958.0
# ['hôtel du Lignon']

# %%
## Reading in the csv file, from FRENCH language Rules-Based NLP results, of the extracted names and coordinates of
## the Schools on the Plateau, creating a pandas dataframe with these locations and their
## coordinates, then creating a list of just the location names, which then becomes one of the lists of keywords.

df_schools = pd.read_csv("YOUR_DATA_keywords")
df_schools = df_schools.dropna()
df_schools = df_schools[["Schools", "LAT", "LON", "ALT"]]
df_schools["LAT"] = pd.to_numeric(df_schools["LAT"], downcast="float")
df_schools["LON"] = pd.to_numeric(df_schools["LON"], downcast="float")
df_schools["ALT"] = pd.to_numeric(df_schools["ALT"], downcast="float")
df_schools.columns = ["Schools", "LAT", "LON", "ALT"]
print(df_schools)
schools = df_schools["Schools"].to_list()
print(schools)
# Out:
#            Schools        LAT       LON    ALT
# 0  collège Cévenol  45.060959  4.303929  961.0
# 1  Collège Cévenol  45.060959  4.303929  961.0
# 2    école Cévenol  45.060959  4.303929  961.0
# 3    Lycée Cévenol  45.060959  4.303929  961.0
# ['collège Cévenol', 'Collège Cévenol', 'école Cévenol', 'Lycée Cévenol']

# %%
## Reading in the csv file, from FRENCH language Rules-Based NLP results, of the extracted non-named
## features mentioned in the testimonies, creating a pandas dataframe with features,
## then creating a list of the features, which then becomes one of the lists of keywords.

df_features = pd.read_csv("YOUR_DATA_keywords")
df_features = df_features.dropna()
df_features = df_features[["Features"]]
df_features.columns = ["Features"]
print(df_features)
features = df_features["Features"].to_list()
print(features)
# Out:
#    Features
# 0   village
# 1     école
# 2    maison
# 3     ferme
# 4   collège
# ..      ...
# 71    ponts
# 72   prison
# 73  plateau
# 74   forêts
# 75    tombe
#
# [76 rows x 1 columns]
# ...

# %%
## Load the FRENCH-language dataset for analysis.

path = "YOUR_DATA_Fre"

def read_txt_files(directory):
    # Reads all .txt files in a directory and returns a combined string of their contents.

    file_contents = ''
    
    for filename in os.listdir(directory):
        if filename.endswith(".txt"):
            filepath = os.path.join(directory, filename)
            with open(filepath, "r", encoding="utf8") as f:
                file_contents = file_contents + (f.read())
    return file_contents

texts = read_txt_files(path)

# %%
# Import FRENCH emotion classification model, and "warm it up" on the simple sentence.
# See site https://huggingface.co/astrosbd/french_emotion_camembert for model
# See site https://huggingface.co/almanach/camembert-base for how to cite base model

from transformers import pipeline
classifier = pipeline("text-classification", model="astrosbd/french_emotion_camembert")

classifier("Je suis très heureux de votre service rapide et efficace.")
# Out:
# Device set to use cuda:0
# [{'label': 'joy', 'score': 0.9963505268096924}]

# %%
## Define function to perform emotion classification on text that is 225 characters on either side of keywords

def detect_emotion_with_context(text, keywords, context_size=225):
    """
    Detects emotions associated with keywords in text, providing surrounding context.

    Args:
        text (str): The input text.
        keywords (list): A list of keywords to search for.
        context_size (int): The number of characters to include as context 
                          around the keyword.  In this case, I used 225 (tried 50, 75, 100, 125, 150, 175, 200, 
                          225, 250, 275, and 350, but results were "best" with 225).

    Returns:
        dict: A dictionary where keys are keywords found, and values are lists 
              of tuples. Each tuple contains:
              - The classified emotion (from hartmann_distil_roberta).
              - The surrounding context of the keyword.
    """
    results = {}
    for keyword in keywords:
        keyword_results = []
        # Case-insensitive search for the keyword with re.IGNORECASE
        for match in re.finditer(r'\b' + re.escape(keyword) + r'\b', text, re.IGNORECASE):
            start = max(0, match.start() - 225)
            end = min(len(text), match.end() + 225)
            context = text[start:end]
            emotion = classifier(context)
            
            keyword_results.append((keyword, emotion, context))
        if keyword_results:
            results[keyword] = keyword_results
    return results

# %%
## IMPORTANT!!  Need to do each set of keywords one at a time, all the way through exporting the results
## to their respective csv file.  This is because the model is run once per set of keywords.

# %%
# PLATEAU LOCATIONS: Run the model on the FRENCH dataset, with Plateau Locations as the keywords in this instance, 
# and print results.

text = texts
keywords = PlatLoc

emotion_data = detect_emotion_with_context(text, keywords)

for keyword, data_list in emotion_data.items():
    #print(f"Keyword: {keyword}")
    for keyword, emotion, context in data_list:
        print(f"  Keyword: {keyword}")
        print(f"  Emotion: {emotion}")
        print(f"  Context: {context}")
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   Keyword: Chambon
#   Emotion: [{'label': 'joy', 'score': 0.9942627549171448}]
#   Context: ue
# la CIMADE une organisation aidée par les quakers des protestants et sans
# comprendre comment et pourquoi fin août 41 on a formé un groupe de 14
# enfants on m'a mis sur une voiture dans un train et je me suis retrouvé
# au Chambon-sur-Lignon grâce à l'action des protestants du Chambon-sur-Lignon
# du pasteur Trocmé du Chambon-sur-Lignon ainsi que de la CIMADE
# j'ai eu donc une chance extraordinaire de me retrouver dans un village
# protestant j'avais po
#   Keyword: Chambon
#   Emotion: [{'label': 'fear', 'score': 0.47543540596961975}]
#   Context: s protestants et sans
# comprendre comment et pourquoi fin août 41 on a formé un groupe de 14
# enfants on m'a mis sur une voiture dans un train et je me suis retrouvé
# ...

# %%
# PLATEAU LOCATIONS: Results of emotion classifications get appended to a list, then converted to a dataframe in lines 1-5. 
# Then, lines 6-8 normalize and remove the list that contained the dictionary of the classified emotion label 
# and score.  Then, lines 9-10 normalize the dictionary and create separate columns for the label and score.  
# Then, lines 11-21 adds a column for the numerical value of the emotion using the key values from the 
# Astrosbd Camembert model.  Lines 22 just displays the final normalized dataframe.

results = []
for keyword, data_list in emotion_data.items():
        for keyword, emotion, context in data_list:
            results.append([keyword, emotion, context])
df_results = pd.DataFrame(results, columns = ["Plateau_Locations", "Emotion", "Context"])
df_norm = pd.json_normalize(df_results["Emotion"])
df_results_norm = pd.concat([df_results, df_norm], axis=1).drop("Emotion", axis=1)
df_results_norm.columns = ["Plateau_Locations", "Context", "Emotion"]
df_norm2 = pd.json_normalize(df_results_norm["Emotion"])
df_results_norm_final = pd.concat([df_results_norm, df_norm2], axis=1).drop("Emotion", axis=1)
conditions = [
    df_results_norm_final["label"] == "anger",
    df_results_norm_final["label"] == "disgust",
    df_results_norm_final["label"] == "fear",
    df_results_norm_final["label"] == "joy",
    df_results_norm_final["label"] == "neutral",
    df_results_norm_final["label"] == "sad",
    df_results_norm_final["label"] == "surprise"
]
values = ["0", "1", "2", "3", "4", "5", "6"]
df_results_norm_final["label_numeric"] = np.select(conditions, values, default="Unknown")
df_results_norm_final
# Out:
#     Plateau_Locations                                            Context  \
# 0             Chambon  ue \nla CIMADE une organisation aidée par les ...
# 1             Chambon  s protestants et sans \ncomprendre comment et ...
# 2             Chambon   et pourquoi fin août 41 on a formé un groupe ...
# 3             Chambon  et beaucoup d'angoisse \ncar de nouveau j'étai...
# 4             Chambon  vais pas ce qu'elle \nallait devenir mais j'ét...
# ..                ...                                                ...
# 635             Tence  nce il y a aussi une chose qui m'avait \nbeauc...
# 636             Tence  béré, un certain nombre de parties \nde la Fra...
# 637             Tence  ncer. Et c'est comme ça que ma mère lavait son...
# 638             Tence  'enterrement de ces gendarmes.\n\nUn autre sou...
# 639             Tence   comment, qui habitait sur place aussi à Tence...
#
#        label     score label_numeric
# 0        joy  0.994263             3
# ...

# %%
# PLATEAU LOCATIONS:  This merges two dataframes: the first is the dataframe with the extracted Plateau locations 
# and their coordinates and the second is the dataframe which contains the contextualized emotions surrounding 
# references to these Plateau locations. Then it exports the results to a csv file.

df_mergedPlatLoc = pd.merge(df_PlatLoc, df_results_norm_final, on="Plateau_Locations", how="right")

df_mergedPlatLoc.to_csv("Results_EmotionsPlateauLocations_Fre.csv", encoding="utf-8-sig", index=False, header=True, mode="w+")

# %%
# COUNT/PROPORTION of EMOTION SCORES of PLATEAU LOCATIONS:  Calculate the COUNT of each emotion detected at a 
# given set of coordinates then calculate the proportion at that location of each emotion...
# The first line is a repeat of the first line in the cell above, thus avoiding having to re-export the 
# primary results. Thus, it merges two dataframes: the first is the dataframe with the extracted locations 
# and their coordinates and the second is the dataframe which contains the contextualized emotions surrounding 
# references to these locations. 
# Then the next line groups by the coordinates of the locations, and COUNTS the occurrences of emotion 
# scores (in the column "label_numeric"), then the "normalize=True" argument calculates and returns the 
# relative frequency of that score.  
# The next line renames the column for "label_numeric" to "emotion_value."
# The next sequence of lines sets conditions to add the "labels" to the "emotion_value" scores.
# The next 3 lines calculates the confidence scores for the detected emotions at each location, merges the
# results with the normalized count dataframe and prints the results.
# Then the next line exports results to a csv.

df_mergedPlatLoc4 = pd.merge(df_PlatLoc, df_results_norm_final, on="Plateau_Locations", how="right")
df_mergedPlatLoc4_count = df_mergedPlatLoc4.groupby(["LAT", "LON", "ALT"], as_index=False)["label_numeric"].value_counts(normalize=True)
df_mergedPlatLoc4_count = df_mergedPlatLoc4_count.rename(columns={"label_numeric": "emotion_value"})
conditions = [
    df_mergedPlatLoc4_count["emotion_value"] == "0",
    df_mergedPlatLoc4_count["emotion_value"] == "1",
    df_mergedPlatLoc4_count["emotion_value"] == "2",
    df_mergedPlatLoc4_count["emotion_value"] == "3",
    df_mergedPlatLoc4_count["emotion_value"] == "4",
    df_mergedPlatLoc4_count["emotion_value"] == "5",
    df_mergedPlatLoc4_count["emotion_value"] == "6"
]
values = ["anger", "disgust", "fear", "joy", "neutral", "sadness", "surprise"]
df_mergedPlatLoc4_count["emotion_label"] = np.select(conditions, values, default="Unknown")
df_mergedPlatLoc4_confScore = df_mergedPlatLoc4.groupby(["LAT", "LON", "ALT"], as_index=False)["score"].mean()
df_mergedPlatLoc4_confScore = df_mergedPlatLoc4_confScore.rename(columns={"score": "average_confidence_score"})
df_mergedPlatLoc4_count_conf = pd.merge(df_mergedPlatLoc4_count, df_mergedPlatLoc4_confScore, on=("LAT", "LON", "ALT"), how="left")
print(df_mergedPlatLoc4_count_conf)
df_mergedPlatLoc4_count_conf.to_csv("Results_EmotionsPlateauLocations_Proportion_Fre.csv", encoding="utf-8-sig", index=False, header=True, mode="w+")
# Out:
#           LAT       LON     ALT emotion_value  proportion emotion_label  \
# 0   44.914280  4.189920  1744.0             4    1.000000       neutral
# 1   44.952831  4.264970  1151.0             4    1.000000       neutral
# 2   44.985435  4.226421  1181.0             4    0.882353       neutral
# 3   44.985435  4.226421  1181.0             5    0.117647       sadness
# 4   45.010014  4.395049  1066.0             4    1.000000       neutral
# 5   45.047192  4.244734  1027.0             4    0.571429       neutral
# 6   45.047192  4.244734  1027.0             5    0.285714       sadness
# 7   45.047192  4.244734  1027.0             0    0.142857         anger
# 8   45.060810  4.302941   961.0             4    0.678245       neutral
# 9   45.060810  4.302941   961.0             3    0.146252           joy
# 10  45.060810  4.302941   961.0             5    0.135283       sadness
# 11  45.060810  4.302941   961.0             6    0.014625      surprise
# ...

# %%
# OTHER FRENCH LOCATIONS: Run the model on the FRENCH dataset, with Other French Locations as the keywords 
# in this instance, and print results.

text = texts
keywords = FranceLoc

emotion_data = detect_emotion_with_context(text, keywords)

for keyword, data_list in emotion_data.items():
    #print(f"Keyword: {keyword}")
    for keyword, emotion, context in data_list:
        print(f"  Keyword: {keyword}")
        print(f"  Emotion: {emotion}")
        print(f"  Context: {context}")
# Out:
#   Keyword: camp de Gurs
#   Emotion: [{'label': 'sad', 'score': 0.8595706820487976}]
#   Context: . Et nous étions tout à fait informés
# de ce qui se passait et nous avions la conscience de l'évolution de la
# guerre. Je voudrais à ce sujet vous raconter deux faits qui m'ont marqué.
#
# Août 1942, la déportation des juifs du camp de Gurs. Nous l'avons su
# immédiatement. Le Chambon-sur-Lignon et tous les enfants juifs qui
# avaient encore des parents à Gurs, et même ceux qui n'en avaient pas, je
# me souviens, autour de moi, c'était comme une ruche d'abeilles.
#
#   Keyword: camp de Gurs
#   Emotion: [{'label': 'sad', 'score': 0.9864874482154846}]
#   Context: r-Lignon, et c'est quelque chose que je
# n'oublierai jamais, il a eu un mot très malheureux pour les enfants. Il a
# dit à mes petits amis, à mes petits camarades d'origine allemande qui
# étaient affolés par la déportation du camp de Gurs, sans qu'on sache
# exactement qu'il s'agissait de la Shoah, mais qu'on pressentait le
# ...

# %%
# OTHER FRENCH LOCATIONS: Results of emotion classifications get appended to a list, then converted to a dataframe in lines 1-5. 
# Then, lines 6-8 normalize and remove the list that contained the dictionary of the classified emotion label 
# and score.  Then, lines 9-10 normalize the dictionary and create separate columns for the label and score.  
# Then, lines 11-21 adds a column for the numerical value of the emotion using the key values from the 
# Astrosbd Camembert model.  Lines 22 just displays the final normalized dataframe.

results = []
for keyword, data_list in emotion_data.items():
        for keyword, emotion, context in data_list:
            results.append([keyword, emotion, context])
df_results = pd.DataFrame(results, columns = ["other_French_Locations", "Emotion", "Context"])
df_norm = pd.json_normalize(df_results["Emotion"])
df_results_norm = pd.concat([df_results, df_norm], axis=1).drop("Emotion", axis=1)
df_results_norm.columns = ["other_French_Locations", "Context", "Emotion"]
df_norm2 = pd.json_normalize(df_results_norm["Emotion"])
df_results_norm_final = pd.concat([df_results_norm, df_norm2], axis=1).drop("Emotion", axis=1)
conditions = [
    df_results_norm_final["label"] == "anger",
    df_results_norm_final["label"] == "disgust",
    df_results_norm_final["label"] == "fear",
    df_results_norm_final["label"] == "joy",
    df_results_norm_final["label"] == "neutral",
    df_results_norm_final["label"] == "sad",
    df_results_norm_final["label"] == "surprise"
]
values = ["0", "1", "2", "3", "4", "5", "6"]
df_results_norm_final["label_numeric"] = np.select(conditions, values, default="Unknown")
df_results_norm_final
# Out:
#     other_French_Locations                                            Context  \
# 0             camp de Gurs  . Et nous étions tout à fait informés \nde ce ...
# 1             camp de Gurs  r-Lignon, et c'est quelque chose que je \nn'ou...
# 2             camp de Gurs  it aussi, donc, au même endroit, ce même villa...
# 3                   Drancy  agiste. Un garagiste qui s'appelait \nmonsieur...
# 4                   Drancy  i les ont emmenés au Puy par la suite j'ai pu ...
# ..                     ...                                                ...
# 169          Saint-Étienne   tout. On ne les voyait jamais.\n\nIl n'y avai...
# 170          Saint-Étienne  vu à Saint-Étienne, mais non, ce n'était pas m...
# 171             Yssingeaux  tes ne sont pas fondés pour faire quelque chos...
# 172             Yssingeaux  rot, je l'ai emmenée chez Mme Barot dans l'esp...
# 173             Yssingeaux  s allemands \narriver à Saint-Étienne en 1940....
#
# ...

# %%
# OTHER FRENCH LOCATIONS:  This merges two dataframes: the first is the dataframe with the extracted other French locations 
# and their coordinates and the second is the dataframe which contains the contextualized emotions surrounding 
# references to these locations. Then it exports the results to a csv file.

df_mergedFranceLoc = pd.merge(df_FranceLoc, df_results_norm_final, on="other_French_Locations", how="right")

df_mergedFranceLoc.to_csv("Results_EmotionsOtherFrenchLocations_Fre.csv", encoding="utf-8-sig", index=False, header=True, mode="w+")

# %%
# COUNT/PROPORTION of EMOTION SCORES of OTHER FRENCH LOCATIONS:  Calculate the COUNT of each emotion detected at a 
# given set of coordinates then calculate the proportion at that location of each emotion...
# The first line is a repeat of the first line in the cell above, thus avoiding having to re-export the 
# primary results. Thus, it merges two dataframes: the first is the dataframe with the extracted locations 
# and their coordinates and the second is the dataframe which contains the contextualized emotions surrounding 
# references to these locations. 
# Then the next line groups by the coordinates of the locations, and COUNTS the occurrences of emotion 
# scores (in the column "label_numeric"), then the "normalize=True" argument calculates and returns the 
# relative frequency of that score.  
# The next line renames the column for "label_numeric" to "emotion_value."
# The next sequence of lines sets conditions to add the "labels" to the "emotion_value" scores.
# The next 3 lines calculates the confidence scores for the detected emotions at each location, merges the
# results with the normalized count dataframe and prints the results.
# Then the next line exports results to a csv.

df_mergedFranceLoc2 = pd.merge(df_FranceLoc, df_results_norm_final, on="other_French_Locations", how="right")
df_mergedFranceLoc2_count = df_mergedFranceLoc2.groupby(["LAT", "LON", "ALT"], as_index=False)["label_numeric"].value_counts(normalize=True)
df_mergedFranceLoc2_count = df_mergedFranceLoc2_count.rename(columns={"label_numeric": "emotion_value"})
conditions = [
    df_mergedFranceLoc2_count["emotion_value"] == "0",
    df_mergedFranceLoc2_count["emotion_value"] == "1",
    df_mergedFranceLoc2_count["emotion_value"] == "2",
    df_mergedFranceLoc2_count["emotion_value"] == "3",
    df_mergedFranceLoc2_count["emotion_value"] == "4",
    df_mergedFranceLoc2_count["emotion_value"] == "5",
    df_mergedFranceLoc2_count["emotion_value"] == "6"
]
values = ["anger", "disgust", "fear", "joy", "neutral", "sadness", "surprise"]
df_mergedFranceLoc2_count["emotion_label"] = np.select(conditions, values, default="Unknown")
df_mergedFranceLoc2_confScore = df_mergedFranceLoc2.groupby(["LAT", "LON", "ALT"], as_index=False)["score"].mean()
df_mergedFranceLoc2_confScore = df_mergedFranceLoc2_confScore.rename(columns={"score": "average_confidence_score"})
df_mergedFranceLoc2_count_conf = pd.merge(df_mergedFranceLoc2_count, df_mergedFranceLoc2_confScore, on=("LAT", "LON", "ALT"), how="left")
print(df_mergedFranceLoc2_count_conf)
df_mergedFranceLoc2_count_conf.to_csv("Results_EmotionsOtherFrenchLocations_Proportion_Fre.csv", encoding="utf-8-sig", index=False, header=True, mode="w+")
# Out:
#           LAT      LON    ALT emotion_value  proportion emotion_label  \
# 0   43.273762 -0.74031  186.0             5    0.500000       sadness
# 1   43.273762 -0.74031  186.0             4    0.400000       neutral
# 2   43.273762 -0.74031  186.0             3    0.100000           joy
# 3   43.296951  5.38107   28.0             4    0.636364       neutral
# 4   43.296951  5.38107   28.0             5    0.272727       sadness
# 5   43.296951  5.38107   28.0             3    0.090909           joy
# 6   44.823132  4.65988  151.0             4    1.000000       neutral
# 7   45.043659  3.88523  640.0             4    0.714286       neutral
# 8   45.043659  3.88523  640.0             5    0.190476       sadness
# 9   45.043659  3.88523  640.0             0    0.095238         anger
# 10  45.142818  4.12372  864.0             4    1.000000       neutral
# 11  45.433891  4.39000  529.0             4    0.645570       neutral
# ...

# %%
# CHILDRENS HOMES: Run the model on the FRENCH dataset, with Childrens Homes as the keywords 
# in this instance, and print results.

text = texts
keywords = homes

emotion_data = detect_emotion_with_context(text, keywords)

for keyword, data_list in emotion_data.items():
    #print(f"Keyword: {keyword}")
    for keyword, emotion, context in data_list:
        print(f"  Keyword: {keyword}")
        print(f"  Emotion: {emotion}")
        print(f"  Context: {context}")
# Out:
#   Keyword: Airelles
#   Emotion: [{'label': 'neutral', 'score': 0.9328445196151733}]
#   Context:  Mme Jouve
# des Heures Claires ne pouvait pas nous donner autre chose que
# l'étiquette.
#
# Et mon père et ma mère, me visitant un jour et voyant ma maigreur,
# cherchent une autre pension. Et me mettent donc chez Mme Jouve aux
# Airelles. Qui, elle, a une petite mini-ferme avec deux vaches, avec des
# abeilles.
#
# Donc, nous avons du miel, nous avons du lait. Nous faisons du beurre à
# tour de rôle avec les copains. Enfin, puisqu'elle a une pension d'enfant,
# on
#   Keyword: Airelles
#   Emotion: [{'label': 'joy', 'score': 0.4751932919025421}]
#   Context: îtresse ou ma mère et son amant sont montés me voir au Chambon sur Lignon
# et ils se sont aperçus ce jour là que je mangeais pas tellement à
# ma faim et c'est ce jour là qu'ils m'ont changé de pension des Heures
# Claires aux Airelles là où c'était le Canaan c'était le pays de cocagne
# ...

# %%
# CHILDRENS HOMES: Results of emotion classifications get appended to a list, then converted to a dataframe in lines 1-5. 
# Then, lines 6-8 normalize and remove the list that contained the dictionary of the classified emotion label 
# and score.  Then, lines 9-10 normalize the dictionary and create separate columns for the label and score.  
# Then, lines 11-21 adds a column for the numerical value of the emotion using the key values from the 
# Astrosbd Camembert model.  Lines 22 just displays the final normalized dataframe.

results = []
for keyword, data_list in emotion_data.items():
        for keyword, emotion, context in data_list:
            results.append([keyword, emotion, context])
df_results = pd.DataFrame(results, columns = ["Childrens_Homes", "Emotion", "Context"])
df_norm = pd.json_normalize(df_results["Emotion"])
df_results_norm = pd.concat([df_results, df_norm], axis=1).drop("Emotion", axis=1)
df_results_norm.columns = ["Childrens_Homes", "Context", "Emotion"]
df_norm2 = pd.json_normalize(df_results_norm["Emotion"])
df_results_norm_final = pd.concat([df_results_norm, df_norm2], axis=1).drop("Emotion", axis=1)
conditions = [
    df_results_norm_final["label"] == "anger",
    df_results_norm_final["label"] == "disgust",
    df_results_norm_final["label"] == "fear",
    df_results_norm_final["label"] == "joy",
    df_results_norm_final["label"] == "neutral",
    df_results_norm_final["label"] == "sad",
    df_results_norm_final["label"] == "surprise"
]
values = ["0", "1", "2", "3", "4", "5", "6"]
df_results_norm_final["label_numeric"] = np.select(conditions, values, default="Unknown")
df_results_norm_final
# Out:
#        Childrens_Homes                                            Context  \
# 0             Airelles   Mme Jouve \ndes Heures Claires ne pouvait pas...
# 1             Airelles  îtresse ou ma mère et son amant sont montés me...
# 2             Airelles  m et c'est ce jour là qu'ils m'ont changé de p...
# 3             Airelles  chelle et puis il y a les Sosets des \ngarçons...
# 4             Grillons   avait personne. Et nous, on rentrait le soir ...
# 5             Grillons  ppelait La Ruchée, ça c'était donc \nprobablem...
# 6             Grillons  ié. J'en avais vu \nà Paris, j'en avais vu à S...
# 7             Grillons  t dans une très belle maison qui s'appelait le...
# 8       Heures Claires  ar le petit chemin de fer, Saint-Agrève, Tence...
# 9       Heures Claires  fumée, on vomissait, parce que de \ntoute faço...
# 10      Joyeuse-Nichée  is pas comment ça se passait, \nil n'y avait p...
# 11           La Ruchée  d'enfants, mais je n'y allais jamais. Chacun r...
# ...

# %%
# CHILDRENS HOMES:  This merges two dataframes: the first is the dataframe with the extracted Childrens Homes 
# and their coordinates and the second is the dataframe which contains the contextualized emotions surrounding 
# references to these locations. Then it exports the results to a csv file.

df_mergedhomes = pd.merge(df_homes, df_results_norm_final, on="Childrens_Homes", how="right")

df_mergedhomes.to_csv("Results_EmotionsChildrensHomes_Fre.csv", encoding="utf-8-sig", index=False, header=True, mode="w+")

# %%
# COUNT/PROPORTION of EMOTION SCORES of CHILDRENS HOMES:  Calculate the COUNT of each emotion detected at a 
# given set of coordinates then calculate the proportion at that location of each emotion...
# The first line is a repeat of the first line in the cell above, thus avoiding having to re-export the 
# primary results. Thus, it merges two dataframes: the first is the dataframe with the extracted locations 
# and their coordinates and the second is the dataframe which contains the contextualized emotions surrounding 
# references to these locations. 
# Then the next line groups by the coordinates of the locations, and COUNTS the occurrences of emotion 
# scores (in the column "label_numeric"), then the "normalize=True" argument calculates and returns the 
# relative frequency of that score.  
# The next line renames the column for "label_numeric" to "emotion_value."
# The next sequence of lines sets conditions to add the "labels" to the "emotion_value" scores.
# The next 3 lines calculates the confidence scores for the detected emotions at each location, merges the
# results with the normalized count dataframe and prints the results.
# Then the next line exports results to a csv.

df_mergedhomes2 = pd.merge(df_homes, df_results_norm_final, on="Childrens_Homes", how="right")
df_mergedhomes2_count = df_mergedhomes2.groupby(["LAT", "LON", "ALT"], as_index=False)["label_numeric"].value_counts(normalize=True)
df_mergedhomes2_count = df_mergedhomes2_count.rename(columns={"label_numeric": "emotion_value"})
conditions = [
    df_mergedhomes2_count["emotion_value"] == "0",
    df_mergedhomes2_count["emotion_value"] == "1",
    df_mergedhomes2_count["emotion_value"] == "2",
    df_mergedhomes2_count["emotion_value"] == "3",
    df_mergedhomes2_count["emotion_value"] == "4",
    df_mergedhomes2_count["emotion_value"] == "5",
    df_mergedhomes2_count["emotion_value"] == "6"
]
values = ["anger", "disgust", "fear", "joy", "neutral", "sadness", "surprise"]
df_mergedhomes2_count["emotion_label"] = np.select(conditions, values, default="Unknown")
df_mergedhomes2_confScore = df_mergedhomes2.groupby(["LAT", "LON", "ALT"], as_index=False)["score"].mean()
df_mergedhomes2_confScore = df_mergedhomes2_confScore.rename(columns={"score": "average_confidence_score"})
df_mergedhomes2_count_conf = pd.merge(df_mergedhomes2_count, df_mergedhomes2_confScore, on=("LAT", "LON", "ALT"), how="left")
print(df_mergedhomes2_count_conf)
df_mergedhomes2_count_conf.to_csv("Results_EmotionsChildrensHomes_Proportion_Fre.csv", encoding="utf-8-sig", index=False, header=True, mode="w+")
# Out:
#          LAT       LON     ALT emotion_value  proportion emotion_label  \
# 0  45.060757  4.304197   958.0             4    1.000000       neutral
# 1  45.060829  4.311157  1002.0             3    1.000000           joy
# 2  45.062370  4.306548   994.0             4    1.000000       neutral
# 3  45.063877  4.309932   981.0             4    0.666667       neutral
# 4  45.063877  4.309932   981.0             5    0.333333       sadness
# 5  45.066315  4.305011   995.0             5    0.500000       sadness
# 6  45.066315  4.305011   995.0             3    0.250000           joy
# 7  45.066315  4.305011   995.0             4    0.250000       neutral
# 8  45.071281  4.326289  1067.0             3    0.500000           joy
# 9  45.071281  4.326289  1067.0             4    0.500000       neutral
#
#    average_confidence_score
# 0                  0.789398
# 1                  0.992786
# 2                  0.906813
# 3                  0.951471
# 4                  0.951471
# ...

# %%
# FARMS: Run the model on the FRENCH dataset, with FARMS as the keywords in this instance, and print results.

text = texts
keywords = farms

emotion_data = detect_emotion_with_context(text, keywords)

for keyword, data_list in emotion_data.items():
    #print(f"Keyword: {keyword}")
    for keyword, emotion, context in data_list:
        print(f"  Keyword: {keyword}")
        print(f"  Emotion: {emotion}")
        print(f"  Context: {context}")
# Out:
#   Keyword: Les Digons
#   Emotion: [{'label': 'neutral', 'score': 0.9790736436843872}]
#   Context:  le 26 novembre 1928 à Paris
# dans le 12e arrondissement.
#
# Il n'avait pas deux ans et demi.  Donc, l' OSE nous a pris et nous a
# envoyés, à un moment donné, dans un lieu dit en Haute-Loire, en pleine
# montagne. Ça s'appelait Les Digons.
#
# Ça s'appelle toujours Les Digons. Et c'était un maçon, il avait une
# petite bicoque et six chèvres.
#
# Et puis, on est arrivé, donc, dans ce petit lieu-dit. C'était en fin
# août, au début septembre 1942.
#
# Et, bon, il fallait
#   Keyword: Les Digons
#   Emotion: [{'label': 'neutral', 'score': 0.9821143746376038}]
#   Context: le 12e arrondissement.
#
# Il n'avait pas deux ans et demi.  Donc, l' OSE nous a pris et nous a
# envoyés, à un moment donné, dans un lieu dit en Haute-Loire, en pleine
# montagne. Ça s'appelait Les Digons.
#
# Ça s'appelle toujours Les Digons. Et c'était un maçon, il avait une
# petite bicoque et six chèvres.
#
# ...

# %%
# FARMS: Results of emotion classifications get appended to a list, then converted to a dataframe in lines 1-5. 
# Then, lines 6-8 normalize and remove the list that contained the dictionary of the classified emotion label 
# and score.  Then, lines 9-10 normalize the dictionary and create separate columns for the label and score.  
# Then, lines 11-21 adds a column for the numerical value of the emotion using the key values from the 
# Astrosbd Camembert model.  Lines 22 just displays the final normalized dataframe.

results = []
for keyword, data_list in emotion_data.items():
        for keyword, emotion, context in data_list:
            results.append([keyword, emotion, context])
df_results = pd.DataFrame(results, columns = ["Farms", "Emotion", "Context"])
df_norm = pd.json_normalize(df_results["Emotion"])
df_results_norm = pd.concat([df_results, df_norm], axis=1).drop("Emotion", axis=1)
df_results_norm.columns = ["Farms", "Context", "Emotion"]
df_norm2 = pd.json_normalize(df_results_norm["Emotion"])
df_results_norm_final = pd.concat([df_results_norm, df_norm2], axis=1).drop("Emotion", axis=1)
conditions = [
    df_results_norm_final["label"] == "anger",
    df_results_norm_final["label"] == "disgust",
    df_results_norm_final["label"] == "fear",
    df_results_norm_final["label"] == "joy",
    df_results_norm_final["label"] == "neutral",
    df_results_norm_final["label"] == "sad",
    df_results_norm_final["label"] == "surprise"
]
values = ["0", "1", "2", "3", "4", "5", "6"]
df_results_norm_final["label_numeric"] = np.select(conditions, values, default="Unknown")
df_results_norm_final
# Out:
#         Farms                                            Context    label  \
# 0  Les Digons   le 26 novembre 1928 à Paris \ndans le 12e arr...  neutral
# 1  Les Digons  le 12e arrondissement.\n\nIl n'avait pas deux ...  neutral
# 2     Remière  dit, ça n'a pas d'importance. Je me suis levé,...  neutral
# 3     Remière  'importance. Je me suis levé, je suis parti. E...  neutral
#
#       score label_numeric
# 0  0.979074             4
# 1  0.982114             4
# 2  0.943323             4
# 3  0.905388             4

# %%
# FARMS:  This merges two dataframes: the first is the dataframe with the extracted Farms 
# and their coordinates and the second is the dataframe which contains the contextualized emotions surrounding 
# references to these locations. Then it exports the results to a csv file.

df_mergedfarms = pd.merge(df_farms, df_results_norm_final, on="Farms", how="right")

df_mergedfarms.to_csv("Results_EmotionsFarms_Fre.csv", encoding="utf-8-sig", index=False, header=True, mode="w+")

# %%
# COUNT/PROPORTION of EMOTION SCORES of FARMS:  Calculate the COUNT of each emotion detected at a 
# given set of coordinates then calculate the proportion at that location of each emotion...
# The first line is a repeat of the first line in the cell above, thus avoiding having to re-export the 
# primary results. Thus, it merges two dataframes: the first is the dataframe with the extracted locations 
# and their coordinates and the second is the dataframe which contains the contextualized emotions surrounding 
# references to these locations. 
# Then the next line groups by the coordinates of the locations, and COUNTS the occurrences of emotion 
# scores (in the column "label_numeric"), then the "normalize=True" argument calculates and returns the 
# relative frequency of that score.  
# The next line renames the column for "label_numeric" to "emotion_value."
# The next sequence of lines sets conditions to add the "labels" to the "emotion_value" scores.
# The next 3 lines calculates the confidence scores for the detected emotions at each location, merges the
# results with the normalized count dataframe and prints the results.
# Then the next line exports results to a csv.

df_mergedfarms2 = pd.merge(df_farms, df_results_norm_final, on="Farms", how="right")
df_mergedfarms2_count = df_mergedfarms2.groupby(["LAT", "LON", "ALT"], as_index=False)["label_numeric"].value_counts(normalize=True)
df_mergedfarms2_count = df_mergedfarms2_count.rename(columns={"label_numeric": "emotion_value"})
conditions = [
    df_mergedfarms2_count["emotion_value"] == "0",
    df_mergedfarms2_count["emotion_value"] == "1",
    df_mergedfarms2_count["emotion_value"] == "2",
    df_mergedfarms2_count["emotion_value"] == "3",
    df_mergedfarms2_count["emotion_value"] == "4",
    df_mergedfarms2_count["emotion_value"] == "5",
    df_mergedfarms2_count["emotion_value"] == "6"
]
values = ["anger", "disgust", "fear", "joy", "neutral", "sadness", "surprise"]
df_mergedfarms2_count["emotion_label"] = np.select(conditions, values, default="Unknown")
df_mergedfarms2_confScore = df_mergedfarms2.groupby(["LAT", "LON", "ALT"], as_index=False)["score"].mean()
df_mergedfarms2_confScore = df_mergedfarms2_confScore.rename(columns={"score": "average_confidence_score"})
df_mergedfarms2_count_conf = pd.merge(df_mergedfarms2_count, df_mergedfarms2_confScore, on=("LAT", "LON", "ALT"), how="left")
print(df_mergedfarms2_count_conf)
df_mergedfarms2_count_conf.to_csv("Results_EmotionsFarms_Proportion_Fre.csv", encoding="utf-8-sig", index=False, header=True, mode="w+")
# Out:
#          LAT       LON     ALT emotion_value  proportion emotion_label  \
# 0  45.036205  4.371174  1084.0             4         1.0       neutral
# 1  45.042877  4.323951  1053.0             4         1.0       neutral
#
#    average_confidence_score
# 0                  0.980594
# 1                  0.924355

# %%
# HOTELS: Run the model on the FRENCH dataset, with HOTELS as the keywords in this instance, and print results.

text = texts
keywords = hotels

emotion_data = detect_emotion_with_context(text, keywords)

for keyword, data_list in emotion_data.items():
    #print(f"Keyword: {keyword}")
    for keyword, emotion, context in data_list:
        print(f"  Keyword: {keyword}")
        print(f"  Emotion: {emotion}")
        print(f"  Context: {context}")
# Out:
#   Keyword: hôtel du Lignon
#   Emotion: [{'label': 'neutral', 'score': 0.9601920247077942}]
#   Context: deux zones, c'est pour ça que Mme
# Barot avait insisté, parce que. Et puis, au Chambon-sur-Lignon, il y a
# eu. À ce moment-là, c'était l'époque de Stalingrad, et il y a un hôtel
# au Chambon-sur-Lignon, le meilleur, c'était l'hôtel du Lignon.
#
# Les Allemands ont amené au Chambon-sur-Lignon tous les blessés de
# Stalingrad, enfin, tous. Ils venaient en convalescence. Il y avait à peu
# près une quarantaine de chambres.
#
# Donc, ils étaient à peu près 80 blessés de Sta

# %%
# HOTELS: Results of emotion classifications get appended to a list, then converted to a dataframe in lines 1-5. 
# Then, lines 6-8 normalize and remove the list that contained the dictionary of the classified emotion label 
# and score.  Then, lines 9-10 normalize the dictionary and create separate columns for the label and score.  
# Then, lines 11-21 adds a column for the numerical value of the emotion using the key values from the 
# Astrosbd Camembert model.  Lines 22 just displays the final normalized dataframe.

results = []
for keyword, data_list in emotion_data.items():
        for keyword, emotion, context in data_list:
            results.append([keyword, emotion, context])
df_results = pd.DataFrame(results, columns = ["Hotels_GermanConvalescence", "Emotion", "Context"])
df_norm = pd.json_normalize(df_results["Emotion"])
df_results_norm = pd.concat([df_results, df_norm], axis=1).drop("Emotion", axis=1)
df_results_norm.columns = ["Hotels_GermanConvalescence", "Context", "Emotion"]
df_norm2 = pd.json_normalize(df_results_norm["Emotion"])
df_results_norm_final = pd.concat([df_results_norm, df_norm2], axis=1).drop("Emotion", axis=1)
conditions = [
    df_results_norm_final["label"] == "anger",
    df_results_norm_final["label"] == "disgust",
    df_results_norm_final["label"] == "fear",
    df_results_norm_final["label"] == "joy",
    df_results_norm_final["label"] == "neutral",
    df_results_norm_final["label"] == "sad",
    df_results_norm_final["label"] == "surprise"
]
values = ["0", "1", "2", "3", "4", "5", "6"]
df_results_norm_final["label_numeric"] = np.select(conditions, values, default="Unknown")
df_results_norm_final
# Out:
#   Hotels_GermanConvalescence  \
# 0            hôtel du Lignon
#
#                                              Context    label     score  \
# 0  deux zones, c'est pour ça que Mme \nBarot avai...  neutral  0.960192
#
#   label_numeric
# 0             4

# %%
# HOTELS:  This merges two dataframes: the first is the dataframe with the extracted Hotels 
# and their coordinates and the second is the dataframe which contains the contextualized emotions surrounding 
# references to these locations. Then it exports the results to a csv file.

df_mergedhotels = pd.merge(df_hotels, df_results_norm_final, on="Hotels_GermanConvalescence", how="right")

df_mergedhotels.to_csv("Results_EmotionsHotels_Fre.csv", encoding="utf-8-sig", index=False, header=True, mode="w+")

# %%
# COUNT/PROPORTION of EMOTION SCORES of HOTELS:  Calculate the COUNT of each emotion detected at a 
# given set of coordinates then calculate the proportion at that location of each emotion...
# The first line is a repeat of the first line in the cell above, thus avoiding having to re-export the 
# primary results. Thus, it merges two dataframes: the first is the dataframe with the extracted locations 
# and their coordinates and the second is the dataframe which contains the contextualized emotions surrounding 
# references to these locations. 
# Then the next line groups by the coordinates of the locations, and COUNTS the occurrences of emotion 
# scores (in the column "label_numeric"), then the "normalize=True" argument calculates and returns the 
# relative frequency of that score.  
# The next line renames the column for "label_numeric" to "emotion_value."
# The next sequence of lines sets conditions to add the "labels" to the "emotion_value" scores.
# The next 3 lines calculates the confidence scores for the detected emotions at each location, merges the
# results with the normalized count dataframe and prints the results.
# Then the next line exports results to a csv.

df_mergedhotels2 = pd.merge(df_hotels, df_results_norm_final, on="Hotels_GermanConvalescence", how="right")
df_mergedhotels2_count = df_mergedhotels2.groupby(["LAT", "LON", "ALT"], as_index=False)["label_numeric"].value_counts(normalize=True)
df_mergedhotels2_count = df_mergedhotels2_count.rename(columns={"label_numeric": "emotion_value"})
conditions = [
    df_mergedhotels2_count["emotion_value"] == "0",
    df_mergedhotels2_count["emotion_value"] == "1",
    df_mergedhotels2_count["emotion_value"] == "2",
    df_mergedhotels2_count["emotion_value"] == "3",
    df_mergedhotels2_count["emotion_value"] == "4",
    df_mergedhotels2_count["emotion_value"] == "5",
    df_mergedhotels2_count["emotion_value"] == "6"
]
values = ["anger", "disgust", "fear", "joy", "neutral", "sadness", "surprise"]
df_mergedhotels2_count["emotion_label"] = np.select(conditions, values, default="Unknown")
df_mergedhotels2_confScore = df_mergedhotels2.groupby(["LAT", "LON", "ALT"], as_index=False)["score"].mean()
df_mergedhotels2_confScore = df_mergedhotels2_confScore.rename(columns={"score": "average_confidence_score"})
df_mergedhotels2_count_conf = pd.merge(df_mergedhotels2_count, df_mergedhotels2_confScore, on=("LAT", "LON", "ALT"), how="left")
print(df_mergedhotels2_count_conf)
df_mergedhotels2_count_conf.to_csv("Results_EmotionsHotels_Proportion_Fre.csv", encoding="utf-8-sig", index=False, header=True, mode="w+")
# Out:
#          LAT      LON    ALT emotion_value  proportion emotion_label  \
# 0  45.060642  4.30448  958.0             4         1.0       neutral
#
#    average_confidence_score
# 0                  0.960192

# %%
# SCHOOLS: Run the model on the FRENCH dataset, with SCHOOLS as the keywords in this instance, and print results.

text = texts
keywords = schools

emotion_data = detect_emotion_with_context(text, keywords)

for keyword, data_list in emotion_data.items():
    #print(f"Keyword: {keyword}")
    for keyword, emotion, context in data_list:
        print(f"  Keyword: {keyword}")
        print(f"  Emotion: {emotion}")
        print(f"  Context: {context}")
# Out:
#   Keyword: collège Cévenol
#   Emotion: [{'label': 'joy', 'score': 0.8792190551757812}]
#   Context: r eux
# non pas un juif mais un hebreu persécuté le chef du village le leader du
# village l'inspirateur du mouvement de la protection des juifs le pasteur
# Trocmé André Trocmé sa femme Magda Trocmé m'ont jugé apte d'aller au
# collège Cévenol c'est déjà extraordinaire qu'il y avait un collège c'est
# à dire une école privée d'enseignement secondaire dans un village de 1500
# habitants à la limite de la Haute-Loire et de l'Ardèche et c'est ainsi
# que j'ai pu continu
#   Keyword: collège Cévenol
#   Emotion: [{'label': 'neutral', 'score': 0.9802185297012329}]
#   Context:
# pantalonnière, si vous voulez.
#
# Et alors, mes frères... Mes frères, là, ont fini l'année sans scolarité,
# la même chose. Et ce n'est qu'à la rentrée, qu'on s'est organisé un peu
# mieux. C'est-à-dire que... Eux sont allés au Collège Cévenol, au
# Chambon-sur-Lignon.
#
# ...

# %%
# SCHOOLS: Results of emotion classifications get appended to a list, then converted to a dataframe in lines 1-5. 
# Then, lines 6-8 normalize and remove the list that contained the dictionary of the classified emotion label 
# and score.  Then, lines 9-10 normalize the dictionary and create separate columns for the label and score.  
# Then, lines 11-21 adds a column for the numerical value of the emotion using the key values from the 
# Astrosbd Camembert model.  Lines 22 just displays the final normalized dataframe.

results = []
for keyword, data_list in emotion_data.items():
        for keyword, emotion, context in data_list:
            results.append([keyword, emotion, context])
df_results = pd.DataFrame(results, columns = ["Schools", "Emotion", "Context"])
df_norm = pd.json_normalize(df_results["Emotion"])
df_results_norm = pd.concat([df_results, df_norm], axis=1).drop("Emotion", axis=1)
df_results_norm.columns = ["Schools", "Context", "Emotion"]
df_norm2 = pd.json_normalize(df_results_norm["Emotion"])
df_results_norm_final = pd.concat([df_results_norm, df_norm2], axis=1).drop("Emotion", axis=1)
conditions = [
    df_results_norm_final["label"] == "anger",
    df_results_norm_final["label"] == "disgust",
    df_results_norm_final["label"] == "fear",
    df_results_norm_final["label"] == "joy",
    df_results_norm_final["label"] == "neutral",
    df_results_norm_final["label"] == "sad",
    df_results_norm_final["label"] == "surprise"
]
values = ["0", "1", "2", "3", "4", "5", "6"]
df_results_norm_final["label_numeric"] = np.select(conditions, values, default="Unknown")
df_results_norm_final
# Out:
#             Schools                                            Context  \
# 0   collège Cévenol  r eux \nnon pas un juif mais un hebreu persécu...
# 1   collège Cévenol  \npantalonnière, si vous voulez.\n\nEt alors, ...
# 2   collège Cévenol  e petite maison de paysans, disons, et puis ve...
# 3   collège Cévenol   manifestaient toutes les nuits. Au premier ét...
# 4   collège Cévenol  gare, et ma mère demande une pension, et le ca...
# 5   collège Cévenol   le pasteur Theis et le pasteur \nTrocmé. Et j...
# 6   collège Cévenol  ermiers, et leur disait, je t'envoie deux livr...
# 7   collège Cévenol  lhouse, et il \nfallait voir pour mes parents ...
# 8   collège Cévenol  Oui, on avait des cours. Il y avait une école....
# 9   Collège Cévenol  r eux \nnon pas un juif mais un hebreu persécu...
# 10  Collège Cévenol  \npantalonnière, si vous voulez.\n\nEt alors, ...
# 11  Collège Cévenol  e petite maison de paysans, disons, et puis ve...
# ...

# %%
# SCHOOLS:  This merges two dataframes: the first is the dataframe with the extracted Schools 
# and their coordinates and the second is the dataframe which contains the contextualized emotions surrounding 
# references to these locations. Then it exports the results to a csv file.

df_mergedschools = pd.merge(df_schools, df_results_norm_final, on="Schools", how="right")

df_mergedschools.to_csv("Results_EmotionsSchools_Fre.csv", encoding="utf-8-sig", index=False, header=True, mode="w+")

# %%
# COUNT/PROPORTION of EMOTION SCORES of SCHOOLS:  Calculate the COUNT of each emotion detected at a 
# given set of coordinates then calculate the proportion at that location of each emotion...
# The first line is a repeat of the first line in the cell above, thus avoiding having to re-export the 
# primary results. Thus, it merges two dataframes: the first is the dataframe with the extracted locations 
# and their coordinates and the second is the dataframe which contains the contextualized emotions surrounding 
# references to these locations. 
# Then the next line groups by the coordinates of the locations, and COUNTS the occurrences of emotion 
# scores (in the column "label_numeric"), then the "normalize=True" argument calculates and returns the 
# relative frequency of that score.  
# The next line renames the column for "label_numeric" to "emotion_value."
# The next sequence of lines sets conditions to add the "labels" to the "emotion_value" scores.
# The next 3 lines calculates the confidence scores for the detected emotions at each location, merges the
# results with the normalized count dataframe and prints the results.
# Then the next line exports results to a csv.

df_mergedschools2 = pd.merge(df_schools, df_results_norm_final, on="Schools", how="right")
df_mergedschools2_count = df_mergedschools2.groupby(["LAT", "LON", "ALT"], as_index=False)["label_numeric"].value_counts(normalize=True)
df_mergedschools2_count = df_mergedschools2_count.rename(columns={"label_numeric": "emotion_value"})
conditions = [
    df_mergedschools2_count["emotion_value"] == "0",
    df_mergedschools2_count["emotion_value"] == "1",
    df_mergedschools2_count["emotion_value"] == "2",
    df_mergedschools2_count["emotion_value"] == "3",
    df_mergedschools2_count["emotion_value"] == "4",
    df_mergedschools2_count["emotion_value"] == "5",
    df_mergedschools2_count["emotion_value"] == "6"
]
values = ["anger", "disgust", "fear", "joy", "neutral", "sadness", "surprise"]
df_mergedschools2_count["emotion_label"] = np.select(conditions, values, default="Unknown")
df_mergedschools2_confScore = df_mergedschools2.groupby(["LAT", "LON", "ALT"], as_index=False)["score"].mean()
df_mergedschools2_confScore = df_mergedschools2_confScore.rename(columns={"score": "average_confidence_score"})
df_mergedschools2_count_conf = pd.merge(df_mergedschools2_count, df_mergedschools2_confScore, on=("LAT", "LON", "ALT"), how="left")
print(df_mergedschools2_count_conf)
df_mergedschools2_count_conf.to_csv("Results_EmotionsSchools_Proportion_Fre.csv", encoding="utf-8-sig", index=False, header=True, mode="w+")
# Out:
#          LAT       LON    ALT emotion_value  proportion emotion_label  \
# 0  45.060959  4.303929  961.0             4     0.73913       neutral
# 1  45.060959  4.303929  961.0             3     0.26087           joy
#
#    average_confidence_score
# 0                  0.913469
# 1                  0.913469

# %%
# FEATURES: Run the model on the FRENCH dataset, with FEATURES as the keywords in this instance, and print results.

text = texts
keywords = features

emotion_data = detect_emotion_with_context(text, keywords)

for keyword, data_list in emotion_data.items():
    #print(f"Keyword: {keyword}")
    for keyword, emotion, context in data_list:
        print(f"  Keyword: {keyword}")
        print(f"  Emotion: {emotion}")
        print(f"  Context: {context}")
# Out:
#   Keyword: village
#   Emotion: [{'label': 'joy', 'score': 0.9898568391799927}]
#   Context: e me suis retrouvé
# au Chambon-sur-Lignon grâce à l'action des protestants du Chambon-sur-Lignon
# du pasteur Trocmé du Chambon-sur-Lignon ainsi que de la CIMADE
# j'ai eu donc une chance extraordinaire de me retrouver dans un village
# protestant j'avais pour bagage une culotte courte et beaucoup d'angoisse
# car de nouveau j'étais séparé de ma mère je ne savais pas ce qu'elle
# allait devenir mais j'étais là avec mon frère.  Donc j'ai eu une chance
# extrao
#   Keyword: village
#   Emotion: [{'label': 'anger', 'score': 0.8152734637260437}]
#   Context: des rafles au Chambon-sur-Lignon
# on m'a protégé personne ne m'a jamais demandé si j'étais juif
# personne ne m'a demandé de pratiquer une quelconque religion bien que
# j'ai vécu parmi les hommes de la Bible j'ai vécu dans un village de la
# France profonde un village de 1500 habitants où beaucoup de gens
# ...

# %%
# FEATURES: Results of emotion classifications get appended to a list, then converted to a dataframe in lines 1-5. 
# Then, lines 6-8 normalize and remove the list that contained the dictionary of the classified emotion label 
# and score.  Then, lines 9-10 normalize the dictionary and create separate columns for the label and score.  
# Then, lines 11-21 adds a column for the numerical value of the emotion using the key values from the 
# Astrosbd Camembert model.  Lines 22 just displays the final normalized dataframe.

results = []
for keyword, data_list in emotion_data.items():
        for keyword, emotion, context in data_list:
            results.append([keyword, emotion, context])
df_results = pd.DataFrame(results, columns = ["Features", "Emotion", "Context"])
df_norm = pd.json_normalize(df_results["Emotion"])
df_results_norm = pd.concat([df_results, df_norm], axis=1).drop("Emotion", axis=1)
df_results_norm.columns = ["Features", "Context", "Emotion"]
df_norm2 = pd.json_normalize(df_results_norm["Emotion"])
df_results_norm_final = pd.concat([df_results_norm, df_norm2], axis=1).drop("Emotion", axis=1)
conditions = [
    df_results_norm_final["label"] == "anger",
    df_results_norm_final["label"] == "disgust",
    df_results_norm_final["label"] == "fear",
    df_results_norm_final["label"] == "joy",
    df_results_norm_final["label"] == "neutral",
    df_results_norm_final["label"] == "sad",
    df_results_norm_final["label"] == "surprise"
]
values = ["0", "1", "2", "3", "4", "5", "6"]
df_results_norm_final["label_numeric"] = np.select(conditions, values, default="Unknown")
df_results_norm_final
# Out:
#     Features                                            Context    label  \
# 0    village  e me suis retrouvé \nau Chambon-sur-Lignon grâ...      joy
# 1    village  des rafles au Chambon-sur-Lignon \non m'a prot...    anger
# 2    village  on m'a protégé personne ne m'a jamais demandé ...  neutral
# 3    village   les bêtes et les paysans \nn'étaient pratique...  neutral
# 4    village  ans \nn'étaient pratiquement pas séparés ou pa...  neutral
# ..       ...                                                ...      ...
# 664  plateau  parle du Chambon-sur-Lignon, mais il y a les \...  neutral
# 665  plateau  Parce qu'il ne faut pas exclure, vous savez, m...  neutral
# 666  plateau  \nNichée. Juste un petit historique du Chambon...  neutral
# 667   forêts  hambon-sur-Lignon le savaient la \nveille ou q...      joy
# 668    tombe  r sur lui et il nous avait dit que s'il y \nav...      sad
#
#         score label_numeric
# 0    0.989857             3
# 1    0.815273             0
# ...

# %%
# FEATURES:  This exports the results above to a csv file.

df_results_norm_final.to_csv("Results_EmotionsFeatures_Fre.csv", encoding="utf-8-sig", index=False, header=True, mode="w+")

# %%
# COUNT/PROPORTION of EMOTION SCORES of FEATURES:  Calculate the COUNT of each emotion detected at a 
# non-named location, ie. feature, then calculate the proportion of each emotion at that feature type...
# The first line groups by the feature name, and COUNTS the occurrences of emotion 
# scores (in the column "label_numeric"), then the "normalize=True" argument calculates and returns the 
# relative frequency of that score.  
# The next line renames the column for "label_numeric" to "emotion_value."
# The next sequence of lines sets conditions to add the "labels" to the "emotion_value" scores.
# The next 3 lines calculates the confidence scores for the detected emotions at each location, merges the
# results with the normalized count dataframe and prints the results.
# Then the next line exports results to a csv.

df_features_count = df_results_norm_final.groupby("Features", as_index=False)["label_numeric"].value_counts(normalize=True)
df_features_count = df_features_count.rename(columns={"label_numeric": "emotion_value"})
conditions = [
    df_features_count["emotion_value"] == "0",
    df_features_count["emotion_value"] == "1",
    df_features_count["emotion_value"] == "2",
    df_features_count["emotion_value"] == "3",
    df_features_count["emotion_value"] == "4",
    df_features_count["emotion_value"] == "5",
    df_features_count["emotion_value"] == "6"
]
values = ["anger", "disgust", "fear", "joy", "neutral", "sadness", "surprise"]
df_features_count["emotion_label"] = np.select(conditions, values, default="Unknown")
df_features_confScore = df_results_norm_final.groupby("Features", as_index=False)["score"].mean()
df_features_confScore = df_features_confScore.rename(columns={"score": "average_confidence_score"})
df_features_count_conf = pd.merge(df_features_count, df_features_confScore, on="Features", how="left")
print(df_features_count_conf)
df_features_count_conf.to_csv("Results_EmotionsFeatures_Proportion_Fre.csv", encoding="utf-8-sig", index=False, header=True, mode="w+")
# Out:
#         Features emotion_value  proportion emotion_label  \
# 0         Gorges             4    0.600000       neutral
# 1         Gorges             5    0.400000       sadness
# 2        Vallées             4    1.000000       neutral
# 3    appartement             4    0.826087       neutral
# 4    appartement             3    0.130435           joy
# ..           ...           ...         ...           ...
# 131        école             3    0.129870           joy
# 132        école             0    0.038961         anger
# 133       écoles             4    1.000000       neutral
# 134       église             4    0.857143       neutral
# 135       église             5    0.142857       sadness
#
#      average_confidence_score
# 0                    0.729461
# 1                    0.729461
# 2                    0.759570
# 3                    0.894168
# 4                    0.894168
# ..                        ...
# 131                  0.858169
# ...
